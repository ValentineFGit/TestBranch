# %% [markdown]
# <a href="https://colab.research.google.com/github/ValentineFGit/TestBranch/blob/master/ChoclateSalesAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import io
from google.colab import files
file_data = files.upload()
# Out:
#      <input type="file" id="files-d7aad054-2efa-4541-a975-e9378ea589b3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d7aad054-2efa-4541-a975-e9378ea589b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_excel(io.BytesIO(file_data.get('datapd.xlsx')))

# %%
#df

from google.colab import data_table
data_table.disable_dataframe_formatter()

data_table.DataTable(df, include_index=False, num_rows_per_page=100)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sales Person</th>
#       <th>Geography</th>
#       <th>Product</th>
#       <th>Amount</th>
#       <th>Units</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Ram Mahesh</td>
#       <td>New Zealand</td>
#       <td>70% Dark Bites</td>
#       <td>1624</td>
#       <td>114</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Brien Boise</td>
#       <td>USA</td>
#       <td>Choco Coated Almonds</td>
#       <td>6706</td>
#       <td>459</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Husein Augar</td>
#       <td>USA</td>
#       <td>Almond Choco</td>
# ...
